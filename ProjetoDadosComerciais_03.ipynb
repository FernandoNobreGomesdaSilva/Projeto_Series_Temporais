# %% [markdown]
# <font color='blue'> # **Este projeto fictício analisa dados de vendas de uma empresa de eletrônicos com o objetivo de prever as vendas para o ano de 2016, utilizando quatro anos de dados históricos. Para o pré-processamento, foi aplicada a transformação por raiz cúbica para normalizar os dados, com a exclusão dos outliers, e a técnica de diferenciação (Differencing) para garantir que a série temporal se tornasse estacionária. Na etapa de previsão, utilizou-se o algoritmo Auto-ARIMA (SARIMA), que é capaz de capturar e modelar tanto as tendências quanto as sazonalidades presentes nos dados, fornecendo uma abordagem precisa e robusta para a projeção de vendas.** </font>

# %% [markdown]
# ## **Carregando os Dados**

# %%
#Import dos pacotes numpy e pandas
import numpy as np
import pandas as pd

# %%
#Abrindo o arquivo com o pandas
path = ('Dados_Comerciais.xlsx')
df = pd.read_excel(path)
df = pd.DataFrame(df)
df.head()
# Out:
#     ID-Produto           Produto         Categoria     Segmento  Fabricante  \
# 0  SKU-0000001   LG K10 TV Power         Celulares  Corporativo          LG
# 1  SKU-0000002  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 2  SKU-0000003    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 3  SKU-0000004    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 4  SKU-0000005    Lavadora 11 Kg  Eletrodomésticos    Doméstico  Electrolux
#
#      Loja     Cidade     Estado          Vendedor  ID-Vendedor  \
# 0  SP8821  São Paulo  São Paulo      Ana Teixeira         1009
# 1  SP8821  São Paulo  São Paulo      Josias Silva         1006
# 2  SP8821  São Paulo  São Paulo      Josias Silva         1006
# 3  SP8821  São Paulo  São Paulo  Mateus Gonçalves         1003
# 4  SP8821  São Paulo  São Paulo     Artur Moreira         1004
#
#    Comissão (Percentual) Data Venda  ValorVenda  Custo
# 0                      2 2012-10-04      679.00    345
# 1                      3 2012-01-01      832.00    712
# 2                      2 2012-02-02      790.00    390
# 3                      3 2012-03-03      765.32    200
# 4                      5 2012-04-04      459.89    234

# %%
# Convertendo a coluna 'data' para o tipo datetime 
df['Data Venda'] = pd.to_datetime(df['Data Venda'])

# %%
df
# Out:
#       ID-Produto           Produto         Categoria     Segmento  Fabricante  \
# 0    SKU-0000001   LG K10 TV Power         Celulares  Corporativo          LG
# 1    SKU-0000002  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 2    SKU-0000003    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 3    SKU-0000004    Lavadora 11 Kg  Eletrodomésticos    Doméstico    Brastemp
# 4    SKU-0000005    Lavadora 11 Kg  Eletrodomésticos    Doméstico  Electrolux
# ..           ...               ...               ...          ...         ...
# 452  SKU-0000453  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 453  SKU-0000454  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
# 454  SKU-0000455  Morotola Moto G5         Celulares    Doméstico    Motorola
# 455  SKU-0000456  Geladeira Duplex  Eletrodomésticos    Doméstico          LG
# 456  SKU-0000457  Geladeira Duplex  Eletrodomésticos    Doméstico    Brastemp
#
#        Loja          Cidade          Estado          Vendedor  ID-Vendedor  \
# 0    SP8821       São Paulo       São Paulo      Ana Teixeira         1009
# 1    SP8821       São Paulo       São Paulo      Josias Silva         1006
# 2    SP8821       São Paulo       São Paulo      Josias Silva         1006
# 3    SP8821       São Paulo       São Paulo  Mateus Gonçalves         1003
# 4    SP8821       São Paulo       São Paulo     Artur Moreira         1004
# ..      ...             ...             ...               ...          ...
# 452   R1295  Rio de Janeiro  Rio de Janeiro     André Pereira         1002
# 453   R1295  Rio de Janeiro  Rio de Janeiro     André Pereira         1002
# 454   R1295  Rio de Janeiro  Rio de Janeiro      Aline Sutter         1008
# 455   R1295  Rio de Janeiro  Rio de Janeiro     André Pereira         1002
# 456   R1295  Rio de Janeiro  Rio de Janeiro     André Pereira         1002
#
#      Comissão (Percentual) Data Venda  ValorVenda  Custo
# 0                        2 2012-10-04      679.00    345
# 1                        3 2012-01-01      832.00    712
# 2                        2 2012-02-02      790.00    390
# 3                        3 2012-03-03      765.32    200
# 4                        5 2012-04-04      459.89    234
# ..                     ...        ...         ...    ...
# 452                      2 2015-09-23      850.00    120
# 453                      2 2015-10-24      678.00    120
# 454                      2 2015-11-25     1230.00    120
# 455                      2 2015-11-26     1234.00    120
# 456                      2 2015-11-27     1234.00    120
#
# [457 rows x 14 columns]

# %% [markdown]
# ## **Análise Exploratória**

# %%
#Informando o número de linhas e colunas
df.shape
# Out:
# (457, 14)

# %%
#Informando os tipos de dados
df.dtypes
# Out:
# ID-Produto                       object
# Produto                          object
# Categoria                        object
# Segmento                         object
# Fabricante                       object
# Loja                             object
# Cidade                           object
# Estado                           object
# Vendedor                         object
# ID-Vendedor                       int64
# Comissão (Percentual)             int64
# Data Venda               datetime64[ns]
# ValorVenda                      float64
# Custo                             int64
# dtype: object

# %%
df_Ajuste = df[['Data Venda','ValorVenda']]

# %%
df_Ajuste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Data Venda  457 non-null    datetime64[ns]
#  1   ValorVenda  457 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.3 KB

# %% [markdown]
# ## **Verificando os valores de outliers**

# %%
# Calculando Q1, Q3 e IQR
Q1 = df_Ajuste['ValorVenda'].quantile(0.25)
Q3 = df_Ajuste['ValorVenda'].quantile(0.75)
IQR = Q3 - Q1

# %%
# Definindos os limites
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %%
# Identificando os outliers com a criação da coluna: Outlier
df_Ajuste = df_Ajuste.copy()  # Garante que você está trabalhando com uma cópia
df_Ajuste.loc[:, 'Outlier'] = (df_Ajuste['ValorVenda'] < limite_inferior) | (df_Ajuste['ValorVenda'] > limite_superior)
df_Ajuste
# Out:
#     Data Venda  ValorVenda  Outlier
# 0   2012-10-04      679.00    False
# 1   2012-01-01      832.00    False
# 2   2012-02-02      790.00    False
# 3   2012-03-03      765.32    False
# 4   2012-04-04      459.89    False
# ..         ...         ...      ...
# 452 2015-09-23      850.00    False
# 453 2015-10-24      678.00    False
# 454 2015-11-25     1230.00    False
# 455 2015-11-26     1234.00    False
# 456 2015-11-27     1234.00    False
#
# [457 rows x 3 columns]

# %%
# Conta quantos valores são ou não outliers
df_Ajuste['Outlier'].value_counts()
# Out:
# Outlier
# False    442
# True      15
# Name: count, dtype: int64

# %%
# Filtra apenas as linhas que são outliers
outliers = df_Ajuste[df_Ajuste['Outlier'] == True]
outliers
# Out:
#     Data Venda  ValorVenda  Outlier
# 147 2013-07-21      3999.0     True
# 150 2013-10-24      3999.0     True
# 154 2014-10-04      3999.0     True
# 156 2014-02-02      3999.0     True
# 157 2014-03-03      3999.0     True
# 158 2014-04-04      3999.0     True
# 159 2014-05-04      3999.0     True
# 169 2015-02-02      3999.0     True
# 170 2015-03-02      3999.0     True
# 171 2015-04-02      3999.0     True
# 172 2015-05-02      3999.0     True
# 173 2015-06-02      3999.0     True
# 174 2015-07-02      3999.0     True
# 175 2015-08-02      3999.0     True
# 176 2015-09-02      3999.0     True

# %%
# Filtra linhas que não são outliers
nao_outliers = df_Ajuste[df_Ajuste['Outlier'] == False]
nao_outliers
# Out:
#     Data Venda  ValorVenda  Outlier
# 0   2012-10-04      679.00    False
# 1   2012-01-01      832.00    False
# 2   2012-02-02      790.00    False
# 3   2012-03-03      765.32    False
# 4   2012-04-04      459.89    False
# ..         ...         ...      ...
# 452 2015-09-23      850.00    False
# 453 2015-10-24      678.00    False
# 454 2015-11-25     1230.00    False
# 455 2015-11-26     1234.00    False
# 456 2015-11-27     1234.00    False
#
# [442 rows x 3 columns]

# %%
#Excluíndo apenas a linhas que possuem Outliers
# Removendo os índices de 147 a 177
ExclisaoOutliers = df_Ajuste.drop(index=range(147, 177))  # range(147, 177) inclui de 147 até 176

# %%
df_Ajuste = ExclisaoOutliers.copy()  # Garante que você está trabalhando com uma cópia
df_Ajuste.loc[:, 'Outlier'] = (ExclisaoOutliers['ValorVenda'] < limite_inferior) | (ExclisaoOutliers['ValorVenda'] > limite_superior)
df_Ajuste
# Out:
#     Data Venda  ValorVenda  Outlier
# 0   2012-10-04      679.00    False
# 1   2012-01-01      832.00    False
# 2   2012-02-02      790.00    False
# 3   2012-03-03      765.32    False
# 4   2012-04-04      459.89    False
# ..         ...         ...      ...
# 452 2015-09-23      850.00    False
# 453 2015-10-24      678.00    False
# 454 2015-11-25     1230.00    False
# 455 2015-11-26     1234.00    False
# 456 2015-11-27     1234.00    False
#
# [427 rows x 3 columns]

# %%
#Visualização de Gráficos
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 4

# %%
plt.boxplot(df_Ajuste['ValorVenda'], vert=False)
plt.title('Boxplot dos Valores')
plt.show()

# %% [markdown]
# ## **Criação da Série**

# %%
# Converter o DataFrame em uma série temporal com a coluna Data Venda como índice
serie_temporal1 = df_Ajuste.set_index('Data Venda')['ValorVenda']

# %%
print(serie_temporal1.index)  # Verifica se o índice está correto
# Out:
# DatetimeIndex(['2012-10-04', '2012-01-01', '2012-02-02', '2012-03-03',
#                '2012-04-04', '2012-05-04', '2012-06-04', '2012-07-04',
#                '2012-08-04', '2012-09-04',
#                ...
#                '2015-05-18', '2015-05-19', '2015-06-20', '2015-07-21',
#                '2015-07-22', '2015-09-23', '2015-10-24', '2015-11-25',
#                '2015-11-26', '2015-11-27'],
#               dtype='datetime64[ns]', name='Data Venda', length=427, freq=None)

# %%
type(serie_temporal1)
# Out:
# pandas.core.series.Series

# %%
serie_temporal1
# Out:
# Data Venda
# 2012-10-04     679.00
# 2012-01-01     832.00
# 2012-02-02     790.00
# 2012-03-03     765.32
# 2012-04-04     459.89
#                ...
# 2015-09-23     850.00
# 2015-10-24     678.00
# 2015-11-25    1230.00
# 2015-11-26    1234.00
# 2015-11-27    1234.00
# Name: ValorVenda, Length: 427, dtype: float64

# %%
# Fornece a frequência da série temporal (Mensal, neste caso) acumulado.
serie_temporal1 = serie_temporal1.resample('ME').sum()
serie_temporal1
# Out:
# Data Venda
# 2012-01-31     2636.87
# 2012-02-29     2258.12
# 2012-03-31     2356.22
# 2012-04-30     3150.76
# 2012-05-31     2500.10
# 2012-06-30     2369.81
# 2012-07-31     3029.87
# 2012-08-31     3100.12
# 2012-09-30     5022.90
# 2012-10-31     3244.87
# 2012-11-30     4108.12
# 2012-12-31     3725.98
# 2013-01-31     7311.87
# 2013-02-28     7893.12
# 2013-03-31     8102.90
# 2013-04-30     8009.87
# 2013-05-31     8106.43
# 2013-06-30     7416.80
# 2013-07-31     5779.87
# 2013-08-31     4757.14
# 2013-09-30     4247.13
# 2013-10-31     6264.10
# 2013-11-30     5995.21
# 2013-12-31     6466.12
# 2014-01-31     4102.00
# 2014-02-28     3814.00
# 2014-03-31     2356.00
# 2014-04-30     2366.00
# 2014-05-31     2361.00
# 2014-06-30     2165.00
# 2014-07-31     2160.00
# 2014-08-31     1052.00
# 2014-09-30     1708.90
# 2014-10-31     3716.00
# 2014-11-30     3170.00
# 2014-12-31     4009.12
# 2015-01-31     9018.57
# 2015-02-28    10373.22
# 2015-03-31    13813.00
# 2015-04-30    12903.45
# 2015-05-31    15899.00
# 2015-06-30     9104.87
# 2015-07-31    10582.00
# 2015-08-31     6456.00
# 2015-09-30    10943.00
# 2015-10-31     9147.34
# 2015-11-30    15519.34
# 2015-12-31     8026.00
# Freq: ME, Name: ValorVenda, dtype: float64

# %%
#Calculo da média anual
media_valor_venda = serie_temporal1.mean()
print('MÉDIA: {:.2f}'.format(media_valor_venda))
# Out:
# MÉDIA: 5887.92

# %%
print(serie_temporal1.index)  # Verifica se o índice está correto
# Out:
# DatetimeIndex(['2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#                '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31',
#                '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31',
#                '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30',
#                '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31',
#                '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31',
#                '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30',
#                '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31',
#                '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31',
#                '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
#                '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31'],
#               dtype='datetime64[ns]', name='Data Venda', freq='ME')

# %%
type(serie_temporal1)
# Out:
# pandas.core.series.Series

# %%
# Confirma se há valores nulos
print(serie_temporal1.isnull().sum())
# Out:
# 0

# %%
# Substituindo vírgulas por pontos e convertendo para numérico
serie_temporal1 = serie_temporal1.replace({',': ''}, regex=True)  # Remove vírgulas de milhares, se necessário
serie_temporal1 = pd.to_numeric(serie_temporal1, errors='coerce')  # Converte para numérico
# Confirmando a conversão
print("Último valor de serie_temporal (corrigido):", serie_temporal1.iloc[-1])
# Out:
# Último valor de serie_temporal (corrigido): 8026.0

# %%
serie_temporal1.plot()
plt.xlabel('Data Venda')
plt.ylabel('ValorVenda')
plt.show()

# %% [markdown]
# ## **Verificando se os dados são normalizados**

# %%
from scipy import stats
import matplotlib.pyplot as plt

stats.probplot(serie_temporal1, dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %% [markdown]
# **Teste Shapiro-Wilk**
#
# CRITÉRIO**
#
# NÍVEL DE SIGNIFICÂNCIA DE 0,05 ou 5% (MAIS UTILIZADO)
#
# QUANDO p > 0,05 (distriburo no**rmal).

# %%
# Executando o teste de Shapiro-Wilk para verificar a normalidade
e, p = stats.shapiro(serie_temporal1)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))

# Avaliando o p-valor para decidir sobre a normalidade dos dados
if p > 0.05:
    print("Dados seguem uma distribuição normal")
else:
    print("Dados não seguem uma distribuição normal")
# Out:
# Estatística de teste: 0.8935322909869513
# p-valor: 0.0003913520515824888
# Dados não seguem uma distribuição normal

# %% [markdown]
# **Teste de Estacionaridade**

# %%
import statsmodels.tsa.stattools
import statsmodels.tsa.stattools as ts

# %% [markdown]
# **Teste KPSS (Kwiatkowski-Phillips-Schmidt-Shin)**
#
# Ha = não é estacionária: estatística do teste > valor crítico.
#
# Ho = é estacionária: estatística do teste <= valor crítico.

# %%
# Realizando o teste KPSS
kpss_result = ts.kpss(serie_temporal1)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(kpss_result[0]))
print('p_valor: {:.4f}'.format(kpss_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in kpss_result[3].items():
    if kpss_result[0] > valor:
        print("Não é estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
    else:
        print("É estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: 0.4380
# p_valor: 0.0608
# Valores Críticos:
# Não é estacionária para o nível de significância de: 10%=> 0.3470
# É estacionária para o nível de significância de: 5%=> 0.4630
# É estacionária para o nível de significância de: 2.5%=> 0.5740
# É estacionária para o nível de significância de: 1%=> 0.7390

# %% [markdown]
# **Teste df (Dickey Fuller)**
#
# Ho = não é estacionária: estatística do teste > valor críti.
#
# Ha = é estacionária: estatística do teste <= valor crítico.

# %%
# Realizando o teste Dickey-Fuller
from statsmodels.tsa.stattools import adfuller

df_result = adfuller(serie_temporal1)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(df_result[0]))
print('p_valor: {:.4f}'.format(df_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in df_result[4].items():
    if df_result[0] < valor:  
        print("É estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
    else:
        print("Não é estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: -3.5245
# p_valor: 0.0074
# Valores Críticos:
# Não é estacionária para o nível de significância de: 1% => -3.6209
# É estacionária para o nível de significância de: 5% => -2.9435
# É estacionária para o nível de significância de: 10% => -2.6104

# %% [markdown]
# ## **Análise e Preparação da Série**

# %% [markdown]
# **Decomposição**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposicao = seasonal_decompose(serie_temporal1)

# %%
decomposicao.plot()

# %% [markdown]
# ## **Realizando a normalidade e transformação dos dados**

# %%
# Transformação por raiz cúbica para normalizar os dados
serie_temporal2 = serie_temporal1 ** (1 / 3)
serie_temporal2
# Out:
# Data Venda
# 2012-01-31    13.815382
# 2012-02-29    13.119451
# 2012-03-31    13.306748
# 2012-04-30    14.660151
# 2012-05-31    13.572269
# 2012-06-30    13.332283
# 2012-07-31    14.470204
# 2012-08-31    14.581185
# 2012-09-30    17.125825
# 2012-10-31    14.804683
# 2012-11-30    16.015766
# 2012-12-31    15.502920
# 2013-01-31    19.409283
# 2013-02-28    19.910534
# 2013-03-31    20.085385
# 2013-04-30    20.008222
# 2013-05-31    20.088301
# 2013-06-30    19.501687
# 2013-07-31    17.946208
# 2013-08-31    16.818295
# 2013-09-30    16.194412
# 2013-10-31    18.433999
# 2013-11-30    18.166369
# 2013-12-31    18.630074
# 2014-01-31    16.007809
# 2014-02-28    15.624048
# 2014-03-31    13.306334
# 2014-04-30    13.325134
# 2014-05-31    13.315741
# 2014-06-30    12.936575
# 2014-07-31    12.926608
# 2014-08-31    10.170413
# 2014-09-30    11.955623
# 2014-10-31    15.489066
# 2014-11-30    14.689931
# 2014-12-31    15.886066
# 2015-01-31    20.815135
# 2015-02-28    21.809106
# 2015-03-31    23.993633
# 2015-04-30    23.454992
# 2015-05-31    25.145287
# 2015-06-30    20.881318
# 2015-07-31    21.954451
# 2015-08-31    18.620350
# 2015-09-30    22.201320
# 2015-10-31    20.913735
# 2015-11-30    24.943520
# 2015-12-31    20.021643
# Freq: ME, Name: ValorVenda, dtype: float64

# %%
# Executando o teste de Shapiro-Wilk para verificar a normalidade
e, p = stats.shapiro(serie_temporal2)
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))

# Avaliando o p-valor para decidir sobre a normalidade dos dados
if p > 0.05:
    print("Dados seguem uma distribuição normal")
else:
    print("Dados não seguem uma distribuição normal")
# Out:
# Estatística de teste: 0.9595918070493302
# p-valor: 0.09719432403017508
# Dados seguem uma distribuição normal

# %%
stats.probplot(serie_temporal1, dist="norm", plot=plt)
plt.title("Normal QQ plot Real ANTES da transformação por raiz cúbica")
plt.show()

# %%
stats.probplot(serie_temporal2, dist="norm", plot=plt)
plt.title("Normal QQ plot Real ÁPOS da transformação por raiz cúbica")
plt.show()

# %%
import seaborn as sns
sns.histplot(serie_temporal1, kde=True)
plt.title('Histograma ANTES da transformação por raiz cúbica, indica dados não normalizados')
plt.show()

# %%
sns.histplot(serie_temporal2, kde=True)
plt.title('Histograma APOS da transformação por raiz cúbica, indica dados normalizados')
plt.show()

# %% [markdown]
# **Teste de Estacionaridade APOS a transformação por raiz cúbica**

# %%
# Realizando o teste KPSS
kpss_result = ts.kpss(serie_temporal2)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(kpss_result[0]))
print('p_valor: {:.4f}'.format(kpss_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in kpss_result[3].items():
    if kpss_result[0] > valor:
        print("Não é estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
    else:
        print("É estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: 0.3557
# p_valor: 0.0963
# Valores Críticos:
# Não é estacionária para o nível de significância de: 10%=> 0.3470
# É estacionária para o nível de significância de: 5%=> 0.4630
# É estacionária para o nível de significância de: 2.5%=> 0.5740
# É estacionária para o nível de significância de: 1%=> 0.7390

# %%
# Realizando o teste Dickey-Fuller
from statsmodels.tsa.stattools import adfuller

df_result = adfuller(serie_temporal2)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(df_result[0]))
print('p_valor: {:.4f}'.format(df_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in df_result[4].items():
    if df_result[0] < valor:  
        print("É estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
    else:
        print("Não é estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: -2.1261
# p_valor: 0.2341
# Valores Críticos:
# Não é estacionária para o nível de significância de: 1% => -3.5925
# Não é estacionária para o nível de significância de: 5% => -2.9315
# Não é estacionária para o nível de significância de: 10% => -2.6041

# %% [markdown]
# **Verificado que os dados estão normalizados, porém ao aplicar os testes de estacionaridade: (KPSS e Dickey-Fuller) os dados não são estacionários**.

# %% [markdown]
# **A técnica de Diferenciação será usada para fazer com que o modelo se torne estacionár**o.

# %%
serie_temporal2_diff = serie_temporal2.diff().dropna()
print(serie_temporal2_diff)
# Out:
# Data Venda
# 2012-02-29   -0.695931
# 2012-03-31    0.187297
# 2012-04-30    1.353402
# 2012-05-31   -1.087882
# 2012-06-30   -0.239986
# 2012-07-31    1.137922
# 2012-08-31    0.110981
# 2012-09-30    2.544640
# 2012-10-31   -2.321143
# 2012-11-30    1.211083
# 2012-12-31   -0.512846
# 2013-01-31    3.906363
# 2013-02-28    0.501251
# 2013-03-31    0.174851
# 2013-04-30   -0.077163
# 2013-05-31    0.080080
# 2013-06-30   -0.586614
# 2013-07-31   -1.555480
# 2013-08-31   -1.127912
# 2013-09-30   -0.623883
# 2013-10-31    2.239587
# 2013-11-30   -0.267630
# 2013-12-31    0.463705
# 2014-01-31   -2.622266
# 2014-02-28   -0.383761
# 2014-03-31   -2.317714
# 2014-04-30    0.018800
# 2014-05-31   -0.009393
# 2014-06-30   -0.379166
# 2014-07-31   -0.009967
# 2014-08-31   -2.756195
# 2014-09-30    1.785210
# 2014-10-31    3.533443
# 2014-11-30   -0.799135
# 2014-12-31    1.196135
# 2015-01-31    4.929069
# 2015-02-28    0.993971
# 2015-03-31    2.184527
# 2015-04-30   -0.538641
# 2015-05-31    1.690296
# 2015-06-30   -4.263969
# 2015-07-31    1.073133
# 2015-08-31   -3.334101
# 2015-09-30    3.580970
# 2015-10-31   -1.287585
# 2015-11-30    4.029785
# 2015-12-31   -4.921877
# Freq: ME, Name: ValorVenda, dtype: float64

# %%
# Realizando o teste KPSS
kpss_result = ts.kpss(serie_temporal2_diff)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(kpss_result[0]))
print('p_valor: {:.4f}'.format(kpss_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in kpss_result[3].items():
    if kpss_result[0] > valor:
        print("Não é estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
    else:
        print("É estacionária para o nível de significância de: {}=> {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: 0.0700
# p_valor: 0.1000
# Valores Críticos:
# É estacionária para o nível de significância de: 10%=> 0.3470
# É estacionária para o nível de significância de: 5%=> 0.4630
# É estacionária para o nível de significância de: 2.5%=> 0.5740
# É estacionária para o nível de significância de: 1%=> 0.7390
# C:\Users\ferna\AppData\Local\Temp\ipykernel_4708\2353178766.py:2: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_result = ts.kpss(serie_temporal2_diff)

# %%
#Realizando o teste Dickey-Fuller
from statsmodels.tsa.stattools import adfuller

df_result = adfuller(serie_temporal2_diff)

# Exibindo os resultados do teste
print('Estatística do teste: {:.4f}'.format(df_result[0]))
print('p_valor: {:.4f}'.format(df_result[1]))
print('Valores Críticos:')

# Iterando pelos valores críticos e verificando se a série é estacionária
for chave, valor in df_result[4].items():
    if df_result[0] < valor:  
        print("É estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
    else:
        print("Não é estacionária para o nível de significância de: {} => {:.4f}".format(chave, valor))
# Out:
# Estatística do teste: -3.9525
# p_valor: 0.0017
# Valores Críticos:
# É estacionária para o nível de significância de: 1% => -3.5886
# É estacionária para o nível de significância de: 5% => -2.9299
# É estacionária para o nível de significância de: 10% => -2.6032

# %% [markdown]
# **Autocorrelação**

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
#Sem a difereciação
plot_acf(serie_temporal2, lags=20)
plt.show()

# %%
plot_acf(serie_temporal2_diff, lags=20)
plt.show()

# %%
#Sem a difereciação
plot_pacf(serie_temporal2, lags=20)
plt.show()

# %%
plot_pacf(serie_temporal2_diff, lags=20)
plt.show()

# %% [markdown]
# ## **Modelo AUTO ARIMA**

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\ferna\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (0.14.2)
# Requirement already satisfied: urllib3 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (69.5.1)
# Requirement already satisfied: packaging>=17.1 in c:\users\ferna\anaconda3\lib\site-packages (from pmdarima) (23.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ferna\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ferna\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ferna\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ferna\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ferna\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in c:\users\ferna\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pmdarima.arima import auto_arima

# %%
### AUTOARIMA
#modelo_auto = auto_arima(serie_temporal2_diff, trace = True, stepwise = False, seasonal=True, max_p=10, max_q=10,
                          #max_P=4, max_Q=4, start_p=0, start_q=0, start_P=0, start_Q=0, m=12,)

modelo_auto = auto_arima(serie_temporal2_diff,trace=True,stepwise=True,seasonal=True,m=12,start_p=1, start_q=1,start_P=1, start_Q=1,max_p=5, 
                         max_q=5,max_P=2, max_Q=2,d=None, D=None,max_order=None)



    #stepwise=True,               # Busca passo a passo para otimização de tempo
    #seasonal=True,               # Mantém sazonalidade ativa
    #m=12,                        # Sazonalidade mensal confirmada
    #start_p=1, start_q=1,        # Valores iniciais baseados em ACF/PACF
    #start_P=1, start_Q=1,        # Valores iniciais para sazonalidade
    #max_p=5, max_q=5,            # Limita os valores máximos para não-sazonal
    #max_P=2, max_Q=2,            # Limita os valores máximos para sazonalidade
    #d=None, D=None,              # Permite que o auto_arima identifique diferenças necessárias
    #max_order=None               # Não limita o somatório dos parâmetros
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=205.310, Time=0.00 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=203.430, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=205.409, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=203.503, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=202.517, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=203.801, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : AIC=204.362, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=199.327, Time=0.03 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=201.213, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=201.250, Time=0.03 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=198.794, Time=0.03 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=200.486, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=200.588, Time=0.05 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=199.682, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : AIC=199.378, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=197.600, Time=0.03 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=199.318, Time=0.08 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=199.389, Time=0.08 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=196.834, Time=0.06 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=198.290, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=198.440, Time=0.07 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=204.395, Time=0.02 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=197.304, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : AIC=203.264, Time=0.03 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.18 sec
#  ARIMA(1,0,1)(0,0,0)[12]             : AIC=195.347, Time=0.03 sec
#  ARIMA(1,0,1)(1,0,0)[12]             : AIC=196.766, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,1)[12]             : AIC=196.934, Time=0.05 sec
#  ARIMA(1,0,1)(1,0,1)[12]             : AIC=inf, Time=0.15 sec
#  ARIMA(0,0,1)(0,0,0)[12]             : AIC=202.832, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[12]             : AIC=201.079, Time=0.00 sec
#  ARIMA(2,0,1)(0,0,0)[12]             : AIC=195.906, Time=0.03 sec
#  ARIMA(1,0,2)(0,0,0)[12]             : AIC=195.600, Time=0.03 sec
#  ARIMA(0,0,2)(0,0,0)[12]             : AIC=201.507, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[12]             : AIC=197.578, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,0)[12]             : AIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(1,0,1)(0,0,0)[12]
# Total fit time: 2.589 seconds

# %%
print('Melhor modelo: ', modelo_auto.aic())
# Out:
# Melhor modelo:  195.34728669498443

# %%
resultado_auto = modelo_auto.fit(serie_temporal2_diff)
print(resultado_auto.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   47
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                 -94.674
# Date:                Mon, 30 Dec 2024   AIC                            195.347
# Time:                        14:54:43   BIC                            200.898
# Sample:                    02-29-2012   HQIC                           197.436
#                          - 12-31-2015
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9498      0.147     -6.455      0.000      -1.238      -0.661
# ma.L1          0.7103      0.251      2.835      0.005       0.219       1.201
# sigma2         3.2355      0.658      4.920      0.000       1.947       4.524
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.55   Jarque-Bera (JB):                 2.67
# Prob(Q):                              0.46   Prob(JB):                         0.26
# Heteroskedasticity (H):               3.02   Skew:                             0.52
# Prob(H) (two-sided):                  0.03   Kurtosis:                         3.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# **Análise dos Resíduos**

# %%
residuos_auto = resultado_auto.resid
residuos_auto()
# Out:
# Data Venda
# 2012-02-29   -0.695931
# 2012-03-31   -0.161846
# 2012-04-30    1.628200
# 2012-05-31   -0.874111
# 2012-06-30   -0.674492
# 2012-07-31    1.380617
# 2012-08-31    0.219735
# 2012-09-30    2.494657
# 2012-10-31   -1.672385
# 2012-11-30    0.193143
# 2012-12-31    0.500279
# 2013-01-31    3.064024
# 2013-02-28    2.035235
# 2013-03-31   -0.794648
# 2013-04-30    0.653339
# 2013-05-31   -0.457280
# 2013-06-30   -0.185744
# 2013-07-31   -1.980686
# 2013-08-31   -1.198325
# 2013-09-30   -0.843935
# 2013-10-31    2.246512
# 2013-11-30    0.263697
# 2013-12-31    0.022211
# 2014-01-31   -2.197633
# 2014-02-28   -1.313260
# 2014-03-31   -1.749357
# 2014-04-30   -0.939869
# 2014-05-31    0.676072
# 2014-06-30   -0.868317
# 2014-07-31    0.246701
# 2014-08-31   -2.940898
# 2014-09-30    1.256468
# 2014-10-31    4.336470
# 2014-11-30   -0.523499
# 2014-12-31    0.808999
# 2015-01-31    5.490462
# 2015-02-28    1.775414
# 2015-03-31    1.867446
# 2015-04-30    0.209650
# 2015-05-31    1.029796
# 2015-06-30   -3.390078
# 2015-07-31   -0.568573
# 2015-08-31   -1.911010
# 2015-09-30    1.771802
# 2015-10-31    0.854933
# 2015-11-30    2.199608
# 2015-12-31   -2.656972
# Freq: ME, dtype: float64

# %%
plt.plot(residuos_auto())
plt.xlabel('Periodo')
plt.ylabel('Valores_Residuais')
plt.show()

# %%
#Seguem uma normalidade apos a aplicação do Auto Arima
stats.probplot(residuos_auto(), dist="norm", plot=plt)
plt.title("Normal QQ plot")
plt.show()

# %%
e, p = stats.shapiro(residuos_auto())
print('Estatística de teste: {}'.format(e))
print('p-valor: {}'.format(p))
# Avaliando o p-valor para decidir sobre a normalidade dos dados
if p > 0.05:
    print("Dados seguem uma distribuição normal")
else:
    print("Dados não seguem uma distribuição normal")
# Out:
# Estatística de teste: 0.9789330141569853
# p-valor: 0.5489165334835622
# Dados seguem uma distribuição normal

# %% [markdown]
# **Autocorrelação**

# %%
plot_acf(residuos_auto(), lags=20)
plt.xlabel('Lags')
plt.ylabel('Intervalo_Confiança')
plt.show()

# %%
plot_pacf(residuos_auto(), lags=20)
plt.xlabel('Lags')
plt.ylabel('Intervalo_Confiança')
plt.show()

# %%
plt.plot(serie_temporal2_diff, label='Série Real')
plt.plot(serie_temporal2_diff-residuos_auto(),color='red', label='Resíduos')
plt.xlabel('Periodo')
plt.ylabel('Valores_Residuais')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# **Previsão**

# %%
previsao_auto = resultado_auto.predict(n_periods=12)
previsao_auto
# Out:
# 2016-01-31    2.787304
# 2016-02-29   -2.647275
# 2016-03-31    2.514281
# 2016-04-30   -2.387968
# 2016-05-31    2.268001
# 2016-06-30   -2.154061
# 2016-07-31    2.045845
# 2016-08-31   -1.943066
# 2016-09-30    1.845450
# 2016-10-31   -1.752738
# 2016-11-30    1.664683
# 2016-12-31   -1.581053
# Freq: ME, dtype: float64

# %% [markdown]
# ## **Reversão da previsão para a escala original**

# %%
#Dados originais sem a diferenciação
serie_temporal1
# Out:
# Data Venda
# 2012-01-31     2636.87
# 2012-02-29     2258.12
# 2012-03-31     2356.22
# 2012-04-30     3150.76
# 2012-05-31     2500.10
# 2012-06-30     2369.81
# 2012-07-31     3029.87
# 2012-08-31     3100.12
# 2012-09-30     5022.90
# 2012-10-31     3244.87
# 2012-11-30     4108.12
# 2012-12-31     3725.98
# 2013-01-31     7311.87
# 2013-02-28     7893.12
# 2013-03-31     8102.90
# 2013-04-30     8009.87
# 2013-05-31     8106.43
# 2013-06-30     7416.80
# 2013-07-31     5779.87
# 2013-08-31     4757.14
# 2013-09-30     4247.13
# 2013-10-31     6264.10
# 2013-11-30     5995.21
# 2013-12-31     6466.12
# 2014-01-31     4102.00
# 2014-02-28     3814.00
# 2014-03-31     2356.00
# 2014-04-30     2366.00
# 2014-05-31     2361.00
# 2014-06-30     2165.00
# 2014-07-31     2160.00
# 2014-08-31     1052.00
# 2014-09-30     1708.90
# 2014-10-31     3716.00
# 2014-11-30     3170.00
# 2014-12-31     4009.12
# 2015-01-31     9018.57
# 2015-02-28    10373.22
# 2015-03-31    13813.00
# 2015-04-30    12903.45
# 2015-05-31    15899.00
# 2015-06-30     9104.87
# 2015-07-31    10582.00
# 2015-08-31     6456.00
# 2015-09-30    10943.00
# 2015-10-31     9147.34
# 2015-11-30    15519.34
# 2015-12-31     8026.00
# Freq: ME, Name: ValorVenda, dtype: float64

# %%
#Dados com a diferenciação aplicada
serie_temporal2_diff
# Out:
# Data Venda
# 2012-02-29   -0.695931
# 2012-03-31    0.187297
# 2012-04-30    1.353402
# 2012-05-31   -1.087882
# 2012-06-30   -0.239986
# 2012-07-31    1.137922
# 2012-08-31    0.110981
# 2012-09-30    2.544640
# 2012-10-31   -2.321143
# 2012-11-30    1.211083
# 2012-12-31   -0.512846
# 2013-01-31    3.906363
# 2013-02-28    0.501251
# 2013-03-31    0.174851
# 2013-04-30   -0.077163
# 2013-05-31    0.080080
# 2013-06-30   -0.586614
# 2013-07-31   -1.555480
# 2013-08-31   -1.127912
# 2013-09-30   -0.623883
# 2013-10-31    2.239587
# 2013-11-30   -0.267630
# 2013-12-31    0.463705
# 2014-01-31   -2.622266
# 2014-02-28   -0.383761
# 2014-03-31   -2.317714
# 2014-04-30    0.018800
# 2014-05-31   -0.009393
# 2014-06-30   -0.379166
# 2014-07-31   -0.009967
# 2014-08-31   -2.756195
# 2014-09-30    1.785210
# 2014-10-31    3.533443
# 2014-11-30   -0.799135
# 2014-12-31    1.196135
# 2015-01-31    4.929069
# 2015-02-28    0.993971
# 2015-03-31    2.184527
# 2015-04-30   -0.538641
# 2015-05-31    1.690296
# 2015-06-30   -4.263969
# 2015-07-31    1.073133
# 2015-08-31   -3.334101
# 2015-09-30    3.580970
# 2015-10-31   -1.287585
# 2015-11-30    4.029785
# 2015-12-31   -4.921877
# Freq: ME, Name: ValorVenda, dtype: float64

# %%
# Reversão (após o modelo AUTO_ARIMA e diferenciação)
previsao_auto = resultado_auto.predict(n_periods=12)
# Último valor da série transformada (raiz cúbica)
ultimo_valor_raiz_cubica = serie_temporal2.iloc[-1]  # Último valor na escala da raiz cúbica
# Reversão da diferenciação: soma cumulativa das previsões + último valor conhecido
previsoes_cumulativas = previsao_auto.cumsum() + ultimo_valor_raiz_cubica
# Reversão da transformação por raiz cúbica: eleva ao cubo
previsoes_originais = previsoes_cumulativas ** 3
# Exibe resultados
print("Resultado da previsão:")
print(previsao_auto)
print("\nPrevisões cumulativas (raiz cúbica):")
print(previsoes_cumulativas)
print("\nPrevisões na escala original:")
print(previsoes_originais)
# Out:
# Resultado da previsão:
# 2016-01-31    2.787304
# 2016-02-29   -2.647275
# 2016-03-31    2.514281
# 2016-04-30   -2.387968
# 2016-05-31    2.268001
# 2016-06-30   -2.154061
# 2016-07-31    2.045845
# 2016-08-31   -1.943066
# 2016-09-30    1.845450
# 2016-10-31   -1.752738
# 2016-11-30    1.664683
# 2016-12-31   -1.581053
# Freq: ME, dtype: float64
#
# Previsões cumulativas (raiz cúbica):
# 2016-01-31    22.808947
# 2016-02-29    20.161672
# 2016-03-31    22.675953
# 2016-04-30    20.287985
# 2016-05-31    22.555986
# 2016-06-30    20.401925
# 2016-07-31    22.447770
# 2016-08-31    20.504705
# 2016-09-30    22.350154
# 2016-10-31    20.597416
# 2016-11-30    22.262100
# 2016-12-31    20.681047
# Freq: ME, dtype: float64
#
# Previsões na escala original:
# 2016-01-31    11866.310982
# 2016-02-29     8195.579110
# 2016-03-31    11659.949077
# 2016-04-30     8350.581939
# 2016-05-31    11475.865651
# 2016-06-30     8492.067649
# 2016-07-31    11311.484855
# 2016-08-31     8621.057564
# 2016-09-30    11164.558858
# 2016-10-31     8738.527331
# 2016-11-30    11033.120981
# 2016-12-31     8845.401810
# Freq: ME, dtype: float64

# %%
previsoes_originais = pd.DataFrame(previsoes_originais)
indice_datas = pd.date_range(start='2016-01-31', periods=len(previsoes_originais), freq='ME')
previsoes_originais.index = indice_datas
previsoes_originais.columns = ['Data Venda']
previsoes_originais.columns = ['ValorVenda']
previsoes_originais
# Out:
#               ValorVenda
# 2016-01-31  11866.310982
# 2016-02-29   8195.579110
# 2016-03-31  11659.949077
# 2016-04-30   8350.581939
# 2016-05-31  11475.865651
# 2016-06-30   8492.067649
# 2016-07-31  11311.484855
# 2016-08-31   8621.057564
# 2016-09-30  11164.558858
# 2016-10-31   8738.527331
# 2016-11-30  11033.120981
# 2016-12-31   8845.401810

# %%
serie_temporal1 = pd.DataFrame(serie_temporal1)
indice_datas = pd.date_range(start='2012-01-31', periods=len(serie_temporal1), freq='ME')
serie_temporal1.index = indice_datas
serie_temporal1.columns = ['Data Venda']
serie_temporal1.columns = ['ValorVenda']
serie_temporal1
# Out:
#             ValorVenda
# 2012-01-31     2636.87
# 2012-02-29     2258.12
# 2012-03-31     2356.22
# 2012-04-30     3150.76
# 2012-05-31     2500.10
# 2012-06-30     2369.81
# 2012-07-31     3029.87
# 2012-08-31     3100.12
# 2012-09-30     5022.90
# 2012-10-31     3244.87
# 2012-11-30     4108.12
# 2012-12-31     3725.98
# 2013-01-31     7311.87
# 2013-02-28     7893.12
# 2013-03-31     8102.90
# 2013-04-30     8009.87
# 2013-05-31     8106.43
# 2013-06-30     7416.80
# 2013-07-31     5779.87
# 2013-08-31     4757.14
# 2013-09-30     4247.13
# 2013-10-31     6264.10
# 2013-11-30     5995.21
# 2013-12-31     6466.12
# 2014-01-31     4102.00
# 2014-02-28     3814.00
# 2014-03-31     2356.00
# 2014-04-30     2366.00
# 2014-05-31     2361.00
# 2014-06-30     2165.00
# 2014-07-31     2160.00
# 2014-08-31     1052.00
# 2014-09-30     1708.90
# 2014-10-31     3716.00
# 2014-11-30     3170.00
# 2014-12-31     4009.12
# 2015-01-31     9018.57
# 2015-02-28    10373.22
# 2015-03-31    13813.00
# 2015-04-30    12903.45
# 2015-05-31    15899.00
# 2015-06-30     9104.87
# 2015-07-31    10582.00
# 2015-08-31     6456.00
# 2015-09-30    10943.00
# 2015-10-31     9147.34
# 2015-11-30    15519.34
# 2015-12-31     8026.00

# %%
seriecomprevisao = pd.concat([serie_temporal1, previsoes_originais], axis=0,ignore_index=True)
seriecomprevisao
# Out:
#       ValorVenda
# 0    2636.870000
# 1    2258.120000
# 2    2356.220000
# 3    3150.760000
# 4    2500.100000
# 5    2369.810000
# 6    3029.870000
# 7    3100.120000
# 8    5022.900000
# 9    3244.870000
# 10   4108.120000
# 11   3725.980000
# 12   7311.870000
# 13   7893.120000
# 14   8102.900000
# 15   8009.870000
# 16   8106.430000
# 17   7416.800000
# 18   5779.870000
# 19   4757.140000
# 20   4247.130000
# 21   6264.100000
# 22   5995.210000
# 23   6466.120000
# 24   4102.000000
# 25   3814.000000
# 26   2356.000000
# 27   2366.000000
# 28   2361.000000
# 29   2165.000000
# 30   2160.000000
# 31   1052.000000
# 32   1708.900000
# 33   3716.000000
# 34   3170.000000
# 35   4009.120000
# 36   9018.570000
# 37  10373.220000
# 38  13813.000000
# 39  12903.450000
# 40  15899.000000
# 41   9104.870000
# 42  10582.000000
# 43   6456.000000
# 44  10943.000000
# 45   9147.340000
# 46  15519.340000
# 47   8026.000000
# 48  11866.310982
# 49   8195.579110
# 50  11659.949077
# 51   8350.581939
# 52  11475.865651
# 53   8492.067649
# 54  11311.484855
# 55   8621.057564
# 56  11164.558858
# 57   8738.527331
# 58  11033.120981
# 59   8845.401810

# %%
previsoes_originais.index = range(59, len(previsoes_originais)+59)
previsoes_originais
# Out:
#       ValorVenda
# 59  11866.310982
# 60   8195.579110
# 61  11659.949077
# 62   8350.581939
# 63  11475.865651
# 64   8492.067649
# 65  11311.484855
# 66   8621.057564
# 67  11164.558858
# 68   8738.527331
# 69  11033.120981
# 70   8845.401810

# %%
seriecomprevisao.plot()
plt.plot(previsoes_originais, color='red', label='Previsão')
plt.legend(loc='best')
plt.show()

# %%
serie_temporal1 = pd.DataFrame(serie_temporal1)
indice_datas = pd.date_range(start='2012-01-31', periods=len(serie_temporal1), freq='ME')
#serie_temporal1.index = indice_datas
serie_temporal1.columns = ['Data Venda']
serie_temporal1.columns = ['ValorVenda']
serie_temporal1
# Out:
#             ValorVenda
# 2012-01-31     2636.87
# 2012-02-29     2258.12
# 2012-03-31     2356.22
# 2012-04-30     3150.76
# 2012-05-31     2500.10
# 2012-06-30     2369.81
# 2012-07-31     3029.87
# 2012-08-31     3100.12
# 2012-09-30     5022.90
# 2012-10-31     3244.87
# 2012-11-30     4108.12
# 2012-12-31     3725.98
# 2013-01-31     7311.87
# 2013-02-28     7893.12
# 2013-03-31     8102.90
# 2013-04-30     8009.87
# 2013-05-31     8106.43
# 2013-06-30     7416.80
# 2013-07-31     5779.87
# 2013-08-31     4757.14
# 2013-09-30     4247.13
# 2013-10-31     6264.10
# 2013-11-30     5995.21
# 2013-12-31     6466.12
# 2014-01-31     4102.00
# 2014-02-28     3814.00
# 2014-03-31     2356.00
# 2014-04-30     2366.00
# 2014-05-31     2361.00
# 2014-06-30     2165.00
# 2014-07-31     2160.00
# 2014-08-31     1052.00
# 2014-09-30     1708.90
# 2014-10-31     3716.00
# 2014-11-30     3170.00
# 2014-12-31     4009.12
# 2015-01-31     9018.57
# 2015-02-28    10373.22
# 2015-03-31    13813.00
# 2015-04-30    12903.45
# 2015-05-31    15899.00
# 2015-06-30     9104.87
# 2015-07-31    10582.00
# 2015-08-31     6456.00
# 2015-09-30    10943.00
# 2015-10-31     9147.34
# 2015-11-30    15519.34
# 2015-12-31     8026.00

# %%
previsoes_originais = pd.DataFrame(previsoes_originais)
indice_datas = pd.date_range(start='2016-01-31', periods=len(previsoes_originais), freq='ME')
previsoes_originais.index = indice_datas
previsoes_originais.columns = ['Data Venda']
previsoes_originais.columns = ['ValorVenda']
previsoes_originais
# Out:
#               ValorVenda
# 2016-01-31  11866.310982
# 2016-02-29   8195.579110
# 2016-03-31  11659.949077
# 2016-04-30   8350.581939
# 2016-05-31  11475.865651
# 2016-06-30   8492.067649
# 2016-07-31  11311.484855
# 2016-08-31   8621.057564
# 2016-09-30  11164.558858
# 2016-10-31   8738.527331
# 2016-11-30  11033.120981
# 2016-12-31   8845.401810

# %%
seriecomprevisao = pd.concat([serie_temporal1, previsoes_originais], axis=0,ignore_index=False)
seriecomprevisao
# Out:
#               ValorVenda
# 2012-01-31   2636.870000
# 2012-02-29   2258.120000
# 2012-03-31   2356.220000
# 2012-04-30   3150.760000
# 2012-05-31   2500.100000
# 2012-06-30   2369.810000
# 2012-07-31   3029.870000
# 2012-08-31   3100.120000
# 2012-09-30   5022.900000
# 2012-10-31   3244.870000
# 2012-11-30   4108.120000
# 2012-12-31   3725.980000
# 2013-01-31   7311.870000
# 2013-02-28   7893.120000
# 2013-03-31   8102.900000
# 2013-04-30   8009.870000
# 2013-05-31   8106.430000
# 2013-06-30   7416.800000
# 2013-07-31   5779.870000
# 2013-08-31   4757.140000
# 2013-09-30   4247.130000
# 2013-10-31   6264.100000
# 2013-11-30   5995.210000
# 2013-12-31   6466.120000
# 2014-01-31   4102.000000
# 2014-02-28   3814.000000
# 2014-03-31   2356.000000
# 2014-04-30   2366.000000
# 2014-05-31   2361.000000
# 2014-06-30   2165.000000
# 2014-07-31   2160.000000
# 2014-08-31   1052.000000
# 2014-09-30   1708.900000
# 2014-10-31   3716.000000
# 2014-11-30   3170.000000
# 2014-12-31   4009.120000
# 2015-01-31   9018.570000
# 2015-02-28  10373.220000
# 2015-03-31  13813.000000
# 2015-04-30  12903.450000
# 2015-05-31  15899.000000
# 2015-06-30   9104.870000
# 2015-07-31  10582.000000
# 2015-08-31   6456.000000
# 2015-09-30  10943.000000
# 2015-10-31   9147.340000
# 2015-11-30  15519.340000
# 2015-12-31   8026.000000
# 2016-01-31  11866.310982
# 2016-02-29   8195.579110
# 2016-03-31  11659.949077
# 2016-04-30   8350.581939
# 2016-05-31  11475.865651
# 2016-06-30   8492.067649
# 2016-07-31  11311.484855
# 2016-08-31   8621.057564
# 2016-09-30  11164.558858
# 2016-10-31   8738.527331
# 2016-11-30  11033.120981
# 2016-12-31   8845.401810

# %%
seriecomprevisao['Data Venda'] = seriecomprevisao.index
seriecomprevisao.reset_index(drop=True, inplace=True)
seriecomprevisao
# Out:
#       ValorVenda Data Venda
# 0    2636.870000 2012-01-31
# 1    2258.120000 2012-02-29
# 2    2356.220000 2012-03-31
# 3    3150.760000 2012-04-30
# 4    2500.100000 2012-05-31
# 5    2369.810000 2012-06-30
# 6    3029.870000 2012-07-31
# 7    3100.120000 2012-08-31
# 8    5022.900000 2012-09-30
# 9    3244.870000 2012-10-31
# 10   4108.120000 2012-11-30
# 11   3725.980000 2012-12-31
# 12   7311.870000 2013-01-31
# 13   7893.120000 2013-02-28
# 14   8102.900000 2013-03-31
# 15   8009.870000 2013-04-30
# 16   8106.430000 2013-05-31
# 17   7416.800000 2013-06-30
# 18   5779.870000 2013-07-31
# 19   4757.140000 2013-08-31
# 20   4247.130000 2013-09-30
# 21   6264.100000 2013-10-31
# 22   5995.210000 2013-11-30
# 23   6466.120000 2013-12-31
# 24   4102.000000 2014-01-31
# 25   3814.000000 2014-02-28
# 26   2356.000000 2014-03-31
# 27   2366.000000 2014-04-30
# 28   2361.000000 2014-05-31
# 29   2165.000000 2014-06-30
# 30   2160.000000 2014-07-31
# 31   1052.000000 2014-08-31
# 32   1708.900000 2014-09-30
# 33   3716.000000 2014-10-31
# 34   3170.000000 2014-11-30
# 35   4009.120000 2014-12-31
# 36   9018.570000 2015-01-31
# 37  10373.220000 2015-02-28
# 38  13813.000000 2015-03-31
# 39  12903.450000 2015-04-30
# 40  15899.000000 2015-05-31
# 41   9104.870000 2015-06-30
# 42  10582.000000 2015-07-31
# 43   6456.000000 2015-08-31
# 44  10943.000000 2015-09-30
# 45   9147.340000 2015-10-31
# 46  15519.340000 2015-11-30
# 47   8026.000000 2015-12-31
# 48  11866.310982 2016-01-31
# 49   8195.579110 2016-02-29
# 50  11659.949077 2016-03-31
# 51   8350.581939 2016-04-30
# 52  11475.865651 2016-05-31
# 53   8492.067649 2016-06-30
# 54  11311.484855 2016-07-31
# 55   8621.057564 2016-08-31
# 56  11164.558858 2016-09-30
# 57   8738.527331 2016-10-31
# 58  11033.120981 2016-11-30
# 59   8845.401810 2016-12-31

# %%
# Extraímos o ano criando nova variável
seriecomprevisao['Data Venda'] = seriecomprevisao['Data Venda'].dt.year
seriecomprevisao
# Out:
#       ValorVenda  Data Venda
# 0    2636.870000        2012
# 1    2258.120000        2012
# 2    2356.220000        2012
# 3    3150.760000        2012
# 4    2500.100000        2012
# 5    2369.810000        2012
# 6    3029.870000        2012
# 7    3100.120000        2012
# 8    5022.900000        2012
# 9    3244.870000        2012
# 10   4108.120000        2012
# 11   3725.980000        2012
# 12   7311.870000        2013
# 13   7893.120000        2013
# 14   8102.900000        2013
# 15   8009.870000        2013
# 16   8106.430000        2013
# 17   7416.800000        2013
# 18   5779.870000        2013
# 19   4757.140000        2013
# 20   4247.130000        2013
# 21   6264.100000        2013
# 22   5995.210000        2013
# 23   6466.120000        2013
# 24   4102.000000        2014
# 25   3814.000000        2014
# 26   2356.000000        2014
# 27   2366.000000        2014
# 28   2361.000000        2014
# 29   2165.000000        2014
# 30   2160.000000        2014
# 31   1052.000000        2014
# 32   1708.900000        2014
# 33   3716.000000        2014
# 34   3170.000000        2014
# 35   4009.120000        2014
# 36   9018.570000        2015
# 37  10373.220000        2015
# 38  13813.000000        2015
# 39  12903.450000        2015
# 40  15899.000000        2015
# 41   9104.870000        2015
# 42  10582.000000        2015
# 43   6456.000000        2015
# 44  10943.000000        2015
# 45   9147.340000        2015
# 46  15519.340000        2015
# 47   8026.000000        2015
# 48  11866.310982        2016
# 49   8195.579110        2016
# 50  11659.949077        2016
# 51   8350.581939        2016
# 52  11475.865651        2016
# 53   8492.067649        2016
# 54  11311.484855        2016
# 55   8621.057564        2016
# 56  11164.558858        2016
# 57   8738.527331        2016
# 58  11033.120981        2016
# 59   8845.401810        2016

# %%
#Reorganizando as colunas por 'Data Venda'.
#df = df.rename(columns={'Data Venda': 'Data_Venda', 'ValorVenda': 'Valor_Venda'})
seriecomprevisao = seriecomprevisao[['Data Venda', 'ValorVenda']]
seriecomprevisao = seriecomprevisao.rename(columns={'Data Venda':'Venda_Acumul_Anual', 'ValorVenda':'Valor_Anual_Venda'})
seriecomprevisao
# Out:
#     Venda_Acumul_Anual  Valor_Anual_Venda
# 0                 2012        2636.870000
# 1                 2012        2258.120000
# 2                 2012        2356.220000
# 3                 2012        3150.760000
# 4                 2012        2500.100000
# 5                 2012        2369.810000
# 6                 2012        3029.870000
# 7                 2012        3100.120000
# 8                 2012        5022.900000
# 9                 2012        3244.870000
# 10                2012        4108.120000
# 11                2012        3725.980000
# 12                2013        7311.870000
# 13                2013        7893.120000
# 14                2013        8102.900000
# 15                2013        8009.870000
# 16                2013        8106.430000
# 17                2013        7416.800000
# 18                2013        5779.870000
# 19                2013        4757.140000
# 20                2013        4247.130000
# 21                2013        6264.100000
# 22                2013        5995.210000
# 23                2013        6466.120000
# 24                2014        4102.000000
# 25                2014        3814.000000
# 26                2014        2356.000000
# 27                2014        2366.000000
# 28                2014        2361.000000
# 29                2014        2165.000000
# 30                2014        2160.000000
# 31                2014        1052.000000
# 32                2014        1708.900000
# 33                2014        3716.000000
# 34                2014        3170.000000
# 35                2014        4009.120000
# 36                2015        9018.570000
# 37                2015       10373.220000
# 38                2015       13813.000000
# 39                2015       12903.450000
# 40                2015       15899.000000
# 41                2015        9104.870000
# 42                2015       10582.000000
# 43                2015        6456.000000
# 44                2015       10943.000000
# 45                2015        9147.340000
# 46                2015       15519.340000
# 47                2015        8026.000000
# 48                2016       11866.310982
# 49                2016        8195.579110
# 50                2016       11659.949077
# 51                2016        8350.581939
# 52                2016       11475.865651
# 53                2016        8492.067649
# 54                2016       11311.484855
# 55                2016        8621.057564
# 56                2016       11164.558858
# 57                2016        8738.527331
# 58                2016       11033.120981
# 59                2016        8845.401810

# %%
import locale
# Configurando o locale para o padrão monetário brasileiro
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
# Agrupando os dados por ano e somando os valores de cada ano
dados_agrupados = seriecomprevisao.groupby('Venda_Acumul_Anual')['Valor_Anual_Venda'].sum()
# Criando uma lista de cores alternadas
cores = ['skyblue', 'blue'] * (len(dados_agrupados) // 2 + 1)
# Criando o gráfico de barras
fig, ax = plt.subplots(figsize=(14, 6))
barras = ax.bar(dados_agrupados.index, dados_agrupados.values, color=cores[:len(dados_agrupados)])
# Adicionando os valores dentro das barras, formatados como moeda brasileira
for barra in barras:
    altura = barra.get_height()
    ax.text(
        barra.get_x() + barra.get_width() / 2,           # Posição no eixo X
        altura - (altura * 0.1),                         # Posição no eixo Y
        locale.currency(altura, grouping=True),          # Texto formatado como moeda
        ha='center', va='bottom', color='black'          # Alinhamento e cor
    )
# Personalizando o gráfico
plt.title('Histórico de vendas por ano e previsão para 2016')
plt.xlabel('Ano')
plt.ylabel('Valor Total (R$)')
#Ajustando a grid para ficar atrás das linhas
ax.set_axisbelow(True)  # Coloca as grades atrás dos dados
plt.grid(True, linestyle='--', alpha=0.7)  # Ajusta o estilo e a opacidade da grade
# Exibe o gráfico
plt.show()

# %%
previsoes_originais['Data Venda'] = previsoes_originais.index
previsoes_originais.reset_index(drop=True, inplace=True)
previsoes_originais
# Out:
#       ValorVenda Data Venda
# 0   11866.310982 2016-01-31
# 1    8195.579110 2016-02-29
# 2   11659.949077 2016-03-31
# 3    8350.581939 2016-04-30
# 4   11475.865651 2016-05-31
# 5    8492.067649 2016-06-30
# 6   11311.484855 2016-07-31
# 7    8621.057564 2016-08-31
# 8   11164.558858 2016-09-30
# 9    8738.527331 2016-10-31
# 10  11033.120981 2016-11-30
# 11   8845.401810 2016-12-31

# %%
# Convertendo a coluna 'Data Venda' para o formato datetime (se ainda não estiver)
previsoes_originais['Data Venda'] = pd.to_datetime(previsoes_originais['Data Venda'])
previsoes_originais
# Out:
#       ValorVenda Data Venda
# 0   11866.310982 2016-01-31
# 1    8195.579110 2016-02-29
# 2   11659.949077 2016-03-31
# 3    8350.581939 2016-04-30
# 4   11475.865651 2016-05-31
# 5    8492.067649 2016-06-30
# 6   11311.484855 2016-07-31
# 7    8621.057564 2016-08-31
# 8   11164.558858 2016-09-30
# 9    8738.527331 2016-10-31
# 10  11033.120981 2016-11-30
# 11   8845.401810 2016-12-31

# %%
import locale
# Configurando o locale para o padrão monetário brasileiro
locale.setlocale(locale.LC_ALL, 'pt_BR.UTF-8')
# Convertendo a coluna 'Data Venda' para o formato datetime
previsoes_originais['Data Venda'] = pd.to_datetime(previsoes_originais['Data Venda'])

# Extraindo apenas o mês para exibição no gráfico
previsoes_originais['Mes'] = previsoes_originais['Data Venda'].dt.strftime('%b')

# Criando uma lista de cores alternadas
cores = ['skyblue', 'blue'] * (len(previsoes_originais) // 2 + 1)

# Criando o gráfico de barras
fig, ax = plt.subplots(figsize=(14, 6))
barras = ax.bar(previsoes_originais['Mes'], previsoes_originais['ValorVenda'], color=cores[:len(previsoes_originais)])

# Adicionando os valores dentro das barras, formatados como moeda brasileira
for barra in barras:
    altura = barra.get_height()
    ax.text(
        barra.get_x() + barra.get_width() / 2,           # Posição no eixo X
        altura - (altura * 0.1),                         # Posição no eixo Y
        locale.currency(altura, grouping=True),          # Texto formatado como moeda
        ha='center', va='bottom', color='black'          # Alinhamento e cor
    )

# Personalizando o gráfico
plt.title('Previsão mensal do ano de 2016')
plt.xlabel('Meses')
plt.ylabel('Valor Total (R$)')
plt.grid(True, linestyle='--', alpha=0.7)  # Ajusta o estilo e a opacidade da grade

# Exibe o gráfico
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %% [markdown]
# # **AVALIANDO O DESEMPENHO**

# %%
# Lista com valores reais de 2015
lista = [
    '10305.57',
    '14372.22',
    '17812.00',
    '16902.45',
    '19898.00',
    '13103.87',
    '14581.00',
    '10455.00',
    '14942.00',
    '9147.34',
    '15519.34',
    '8026.00']
valores_reais = pd.DataFrame(lista, columns = ['valores reais'])
print(valores_reais)
# Out:
#    valores reais
# 0       10305.57
# 1       14372.22
# 2       17812.00
# 3       16902.45
# 4       19898.00
# 5       13103.87
# 6       14581.00
# 7       10455.00
# 8       14942.00
# 9        9147.34
# 10      15519.34
# 11       8026.00

# %%
auto = previsoes_originais.iloc[0:12].reset_index(drop=True)
auto
# Out:
#       ValorVenda Data Venda  Mes
# 0   11866.310982 2016-01-31  jan
# 1    8195.579110 2016-02-29  fev
# 2   11659.949077 2016-03-31  mar
# 3    8350.581939 2016-04-30  abr
# 4   11475.865651 2016-05-31  mai
# 5    8492.067649 2016-06-30  jun
# 6   11311.484855 2016-07-31  jul
# 7    8621.057564 2016-08-31  ago
# 8   11164.558858 2016-09-30  set
# 9    8738.527331 2016-10-31  out
# 10  11033.120981 2016-11-30  nov
# 11   8845.401810 2016-12-31  dez

# %%
auto = auto.rename(columns={'ValorVenda': 'Previsão_SARIMA'})
auto
# Out:
#     Previsão_SARIMA Data Venda  Mes
# 0      11866.310982 2016-01-31  jan
# 1       8195.579110 2016-02-29  fev
# 2      11659.949077 2016-03-31  mar
# 3       8350.581939 2016-04-30  abr
# 4      11475.865651 2016-05-31  mai
# 5       8492.067649 2016-06-30  jun
# 6      11311.484855 2016-07-31  jul
# 7       8621.057564 2016-08-31  ago
# 8      11164.558858 2016-09-30  set
# 9       8738.527331 2016-10-31  out
# 10     11033.120981 2016-11-30  nov
# 11      8845.401810 2016-12-31  dez

# %%
desempenho = pd.concat([valores_reais, auto],axis=1)
desempenho
# Out:
#    valores reais  Previsão_SARIMA Data Venda  Mes
# 0       10305.57     11866.310982 2016-01-31  jan
# 1       14372.22      8195.579110 2016-02-29  fev
# 2       17812.00     11659.949077 2016-03-31  mar
# 3       16902.45      8350.581939 2016-04-30  abr
# 4       19898.00     11475.865651 2016-05-31  mai
# 5       13103.87      8492.067649 2016-06-30  jun
# 6       14581.00     11311.484855 2016-07-31  jul
# 7       10455.00      8621.057564 2016-08-31  ago
# 8       14942.00     11164.558858 2016-09-30  set
# 9        9147.34      8738.527331 2016-10-31  out
# 10      15519.34     11033.120981 2016-11-30  nov
# 11       8026.00      8845.401810 2016-12-31  dez

# %% [markdown]
# # **ERRO MÉDIO ABSOLUTO (MAE)**

# %%
print('ERRO MÉDIO ABSOLUTO (MAE)') # media_valor_venda
mae_sarima = mean_absolute_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'])
print('SARIMA: {:.2f}'.format(mae_sarima))

try:
    print('MÉDIA: {:.2f}'.format(media_valor_venda))
except NameError:
    print('Erro: A variável "media_valor_venda" não foi definida.')
    
resultado = (lambda mae_sarima, media: 'Modelo aprovado' if mae_sarima < media else 'Modelo não aprovado')(mae_sarima, media_valor_venda)
print(resultado)
# Out:
# ERRO MÉDIO ABSOLUTO (MAE)
# SARIMA: 4172.55
# MÉDIA: 5887.92
# Modelo aprovado

# %% [markdown]
# # **ERRO QUADRÁTICO MÉDIO (MSE)**

# %%
print('ERRO QUADRÁTICO MÉDIO (MSE)')
mse_sarima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'])
print('SARIMA: {:.2f}'.format(mse_sarima))

def calcular_media_valor_venda(media_valor_venda):
    media_valor_venda_ao_quadrado = media_valor_venda ** 2
    return media_valor_venda_ao_quadrado

try:
    media_ao_quadrado = calcular_media_valor_venda(media_valor_venda)
    print('MÉDIA: {:.2f}'.format(media_ao_quadrado))
    
    percentual_mse = (mse_sarima / media_ao_quadrado) * 100
    print('%: {:.2f}'.format(percentual_mse))

    if percentual_mse < 10:
        print('Modelo excelente')
    elif percentual_mse < 30:
        print('Modelo bom')
    elif percentual_mse < 50:
        print('Modelo razoável')
    else:
        print('Modelo rejeitado')

except NameError:
    print('Erro: A variável "media_valor_venda" não foi definida.')
# Out:
# ERRO QUADRÁTICO MÉDIO (MSE)
# SARIMA: 24421407.90
# MÉDIA: 34667589.66
# %: 70.44
# Modelo rejeitado

# %% [markdown]
# # **RAIZ DO ERRO QUADRÁTICO MÉDIO (RMSE)**

# %%
from sklearn.metrics import mean_squared_error
print('RAIZ DO ERRO QUADRÁTICO MÉDIO (RMSE)')
mse_sarima = mean_squared_error(desempenho['valores reais'], desempenho['Previsão_SARIMA'])
rmse_sarima = np.sqrt(mse_sarima)
print('SARIMA: {:.2f}'.format(rmse_sarima))

try:
    print('MÉDIA: {:.2f}'.format(media_valor_venda))
except NameError:
    print('Erro: A variável "media_valor_venda" não foi definida.')

resultado = (lambda rmse_sarima, media: 'Modelo aprovado' if rmse_sarima < media else 'Modelo não aprovado')(rmse_sarima, media_valor_venda)
print(resultado)
# Out:
# RAIZ DO ERRO QUADRÁTICO MÉDIO (RMSE)
# SARIMA: 4941.80
# MÉDIA: 5887.92
# Modelo aprovado

# %% [markdown]
# # **ERRO PERCENTUAL MÉDIA ABSOLUTO (MAPE)**

# %%
print('ERRO PERCENTUAL MÉDIA ABSOLUTO (MAPE)')
desempenho['valores reais'] = pd.to_numeric(desempenho['valores reais'], errors='coerce')
mape_sarima = np.mean(np.abs((desempenho['valores reais'] - desempenho['Previsão_SARIMA']) / desempenho['valores reais'])) * 100
print('SARIMA: {:.2f}%'.format(mape_sarima))

try:
    print('MÉDIA: {:.2f}'.format(media_valor_venda))
except NameError:
    print('Erro: A variável "media_valor_venda" não foi definida.')
    
if mape_sarima < 10: 
    print('Modelo excelente')
elif mape_sarima < 20: 
    print('Modelo bom')
elif mape_sarima < 50:
    print('Modelo razoável') 
else: 
    print('Modelo ruim')
# Out:
# ERRO PERCENTUAL MÉDIA ABSOLUTO (MAPE)
# SARIMA: 27.47%
# MÉDIA: 5887.92
# Modelo razoável
